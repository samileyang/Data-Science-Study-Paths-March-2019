# %% [markdown]
# <a href="https://colab.research.google.com/github/samileyang/Data-Science-Study-Paths-March-2019/blob/master/hm01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Homework 01 - Instructions
#
# ![](https://github.com/rpi-techfundamentals/hm-01-starter/blob/master/notsaved.png?raw=1)
#
# **WARNING!!!  If you see this icon on the top of your COLAB sesssion, your work is not saved automatically.**
#
#
# **When you are working on homeworks, make sure that you save often. You may find it easier to save intermident copies in Google drive. If you save your working file in Google drive all changes will be saved as you work. MAKE SURE that your final version is saved to GitHub.**
#
# Before you turn this problem in, make sure everything runs as expected. First, restart the kernel (in the menubar, select Kernel → Restart) and then run all cells (in the menubar, select Cell → Run All).  You can speak with others regarding the assignment but all work must be your own.
#
#
# ### This is a 30 point assignment graded from answers to questions and automated tests that should be run at the bottom. Be sure to clearly label all of your answers and commit final tests at the end.

# %% [markdown]
# ## BEFORE YOU BEGIN
#
# Please work through each of these notebooks, which will give you some understanding of the Google Colab environment.
#
# ### Working with Notebooks in Colaboratory
# - [Overview of Colaboratory](https://colab.research.google.com/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](https://colab.research.google.com/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](https://colab.research.google.com/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
#
#
# ### Working with Data
# Some of this is a bit more advanced, but at this point just make sure you know where the code is for how to upload and download a file.
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](https://colab.research.google.com/notebooks/io.ipynb)

# %% [markdown]
# ## Run these Cells
# This will setup the automated testing environment on Colab

# %%
files = "https://github.com/rpi-techfundamentals/hm-01-starter/raw/master/files.zip" 
# !pip install git+https://github.com/data-8/Gofer-Grader && wget $files && unzip -o files.zip
# Out:
# Collecting git+https://github.com/data-8/Gofer-Grader
#   Cloning https://github.com/data-8/Gofer-Grader to /tmp/pip-req-build-jenvv3ch
#   Running command git clone -q https://github.com/data-8/Gofer-Grader /tmp/pip-req-build-jenvv3ch
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from gofer-grader==1.0.9) (2.10.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from gofer-grader==1.0.9) (2.1.3)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from gofer-grader==1.0.9) (4.5.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->gofer-grader==1.0.9) (1.1.1)
# Building wheels for collected packages: gofer-grader
#   Building wheel for gofer-grader (setup.py) ... done
#   Created wheel for gofer-grader: filename=gofer_grader-1.0.9-cp36-none-any.whl size=10113 sha256=109400d39826587c58678af7979aa61640f4c71f1f2d7c75ddc1188d29c40c63
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ud7r7mcq/wheels/9e/62/24/8563ae039051d6ba979557d1766bfebbda5dd08f8572e3e35d
# Successfully built gofer-grader
# Installing collected packages: gofer-grader
# Successfully installed gofer-grader-1.0.9
# --2019-08-30 20:08:45--  https://github.com/rpi-techfundamentals/hm-01-starter/raw/master/files.zip
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/rpi-techfundamentals/hm-01-starter/master/files.zip [following]
# --2019-08-30 20:08:45--  https://raw.githubusercontent.com/rpi-techfundamentals/hm-01-starter/master/files.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 410260 (401K) [application/zip]
# Saving to: ‘files.zip’
#
# files.zip           100%[===================>] 400.64K  --.-KB/s    in 0.03s
#
# 2019-08-30 20:08:46 (13.0 MB/s) - ‘files.zip’ saved [410260/410260]
#
# Archive:  files.zip
#   inflating: md_result.png
#    creating: __MACOSX/
#   inflating: __MACOSX/._md_result.png
#    creating: tests/
#   inflating: tests/q01.py
#   inflating: tests/q05.py
#   inflating: tests/q04.py
#  extracting: tests/__init__.py
#   inflating: tests/qname.py
#   inflating: tests/q03.py
#   inflating: tests/q02.py
#    creating: tests/.ipynb_checkpoints/
#   inflating: hm01.ok
#   inflating: notsaved.png
#   inflating: __MACOSX/._notsaved.png
#   inflating: Demographic_Statistics_By_Zip_Code.parq

# %%
#Run this. It initiates autograding. 
from client.api.notebook import Notebook
ok = Notebook('lab01.ok')
_ = ok.auth(inline=True)

# %% [markdown]
# **Question 1.**
#
# In the next cell, assign the value for `x` too 150.  Set the value for `y` to 13 times `x` , and set the value for `z` to `y` divided by `x` squared.

# %%
#enter your answer here

x = 150
y = 13*x
z = y/(x**2)

# %%
#Run this cell to see if you passed the test.  If it fails, you probably didn't run the above required code. 
_ = ok.grade('q01')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# **Question 2.**
#
# Packages are really important compontent of most programming languages.
#
# In the overview, you learnned about tab completion as a way to explore python objects.  This can be really useful.  Let's use it to find the formula for the the factorial of 99.

# %%
#we have to first import the math function to use tab completion. 
import math

# %%
m = math.factorial(15)
m
# Out:
# 1307674368000

# %%
#Run this cell to see if you passed the test.  If it fails, you probably didn't run the above required code. 
_ = ok.grade('q02')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# **Question 3.**
#
# Markdown is a useful aspect of Jupyter Notebooks.
# - [Guide to Markdown](https://colab.research.google.com/notebooks/markdown_guide.ipynb)
#
# Use what you learned about markdown to adjust the text below to create the following:
# ![](https://github.com/rpi-techfundamentals/hm-01-starter/blob/master/md_result.png?raw=1)

# %% [markdown]
# Header
# For the above header, make it an h1 tag using markdown.
#
# Sub-Header
# For the above sub-header, make it an h5 tag using markdown.
#
# Bold
#
# Italics
#
# https://tw.rpi.edu//images/rpi-logo-red.jpg
# (Embed this image)

# %%
#Ender your updated markdown here Must maatch exactly
markdown="""
# Header For the above header, make it an h1 tag using markdown.    
##### Sub-Header For the above sub-header, make it an h5 tag using markdown.  
**Bold**  
_Italics_  
![](https://tw.rpi.edu//images/rpi-logo-red.jpg) 
"""

# %%
#Run this cell to see if you passed the test.  If it fails, you probably didn't run the above required code. 
#This creates a hash. Read more about it here: https://www.geeksforgeeks.org/md5-hash-python/
import hashlib 
result = hashlib.md5(markdown.encode()).hexdigest()
_ = ok.grade('q03')
# Out:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>/content/tests/q03.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span>result
# <span style="color: #888888">&#39;45470cb631302c5287d59d150eed91b6&#39;</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     result
# Expecting:
#     '45470cb631302c5287d59d150eed91b6'
# **********************************************************************
# Line 2, in /content/tests/q03.py 0
# Failed example:
#     result
# Expected:
#     '45470cb631302c5287d59d150eed91b6'
# Got:
#     '9c02f4d18d86af2bd0ff6ffda40a0c28'
# </pre></p>
#      </li>
#
#             </ul>

# %% [markdown]
# **Question 4.**
#
# ### Installing Packages
# Python packages are an important part of data science and critical to leveraging the broader Python ecosystem.
#
# You typically have two options when installing a package. You can install it with [Conda](http://anaconda.org) or [pip](https://pypi.org).
#
# The `!` in a jupyter notebook means that the line is being processed on the `commmand line` and not by the Python interpreter.
#
# ```
# !conda install -c conda-forge <packagename>
#
# !pip install <packagename>
#
# ```
#
# If you try to import something and get an error, it is usally a tell that you need to install a package.

# %% [markdown]
# ### Install the `fasptparquet` Package to be able to work with Parquet Files
# - CSV (comma delimited  files are great for humans to read and understand.
# - For "big data" though, it isn't a great long term storage option (inefficient/slow).
# - Parquet is a type columnar storage format.  It makes dealing with lots of columns fast.
# - [fastparquet](https://fastparquet.readthedocs.io) is a Python package for dealing with Parquet files.
# - Apache Spark also natively reads Parquet Files.
# - Look [here](https://anaconda.org/conda-forge/fastparquet) for instructions on installing the fastparquet package.

# %%
#Install package for fastparquet here.

# %%
#This gets a parque file we can use to test. 
# !wget https://github.com/rpi-techfundamentals/hm-01-starter/raw/master/Demographic_Statistics_By_Zip_Code.parq
# Out:
# --2019-08-30 20:11:18--  https://github.com/rpi-techfundamentals/hm-01-starter/raw/master/Demographic_Statistics_By_Zip_Code.parq
# Resolving github.com (github.com)... 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/rpi-techfundamentals/hm-01-starter/master/Demographic_Statistics_By_Zip_Code.parq [following]
# --2019-08-30 20:11:18--  https://raw.githubusercontent.com/rpi-techfundamentals/hm-01-starter/master/Demographic_Statistics_By_Zip_Code.parq
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 103532 (101K) [application/octet-stream]
# Saving to: ‘Demographic_Statistics_By_Zip_Code.parq.1’
#
# Demographic_Statist 100%[===================>] 101.11K  --.-KB/s    in 0.02s
#
# 2019-08-30 20:11:19 (4.65 MB/s) - ‘Demographic_Statistics_By_Zip_Code.parq.1’ saved [103532/103532]

# %%
# !pip install fastparquet
#Run this to try to load the name.parq. It won't work unless you downloaded the file and installed the package. 
from fastparquet import ParquetFile  #This imports the package. 
pf = ParquetFile('Demographic_Statistics_By_Zip_Code.parq')
dfparq = pf.to_pandas()   #This changes the Parquet File object to a pandas dataframe. We will learn more about that later. 
dfparq  #Just listing the value prints it out.
# Out:
# Collecting fastparquet
#   Downloading https://files.pythonhosted.org/packages/58/49/dccb790fa17ab3fbf84a6b848050083c7a1899e9586000e34e3e4fbf5538/fastparquet-0.3.2.tar.gz (151kB)
#      |████████████████████████████████| 153kB 4.9MB/s
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.6/dist-packages (from fastparquet) (0.24.2)
# Requirement already satisfied: numba>=0.28 in /usr/local/lib/python3.6/dist-packages (from fastparquet) (0.40.1)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.6/dist-packages (from fastparquet) (1.16.4)
# Collecting thrift>=0.11.0 (from fastparquet)
#   Downloading https://files.pythonhosted.org/packages/c6/b4/510617906f8e0c5660e7d96fbc5585113f83ad547a3989b80297ac72a74c/thrift-0.11.0.tar.gz (52kB)
#      |████████████████████████████████| 61kB 26.3MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fastparquet) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->fastparquet) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->fastparquet) (2018.9)
# Requirement already satisfied: llvmlite>=0.25.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba>=0.28->fastparquet) (0.29.0)
# Building wheels for collected packages: fastparquet, thrift
#   Building wheel for fastparquet (setup.py) ... done
#   Created wheel for fastparquet: filename=fastparquet-0.3.2-cp36-cp36m-linux_x86_64.whl size=253213 sha256=1ae60dcc9b0537ddacbbc6c676dc04867127fff85d645f3d4363b5b61216ec79
#   Stored in directory: /root/.cache/pip/wheels/b9/36/13/01416a760ddcab0eb8281ec9c9ffcbed945c9b831647c8b904
#   Building wheel for thrift (setup.py) ... done
#   Created wheel for thrift: filename=thrift-0.11.0-cp36-cp36m-linux_x86_64.whl size=326448 sha256=b01917be000ca0aec4ba32def6e43d323665c8906f0a469c0bd25b67262daab7
#   Stored in directory: /root/.cache/pip/wheels/be/36/81/0f93ba89a1cb7887c91937948519840a72c0ffdd57cac0ae8f
# Successfully built fastparquet thrift
# Installing collected packages: thrift, fastparquet
# Successfully installed fastparquet-0.3.2 thrift-0.11.0
#      JURISDICTION NAME  ...  PERCENT PUBLIC ASSISTANCE TOTAL
# 0                10001  ...                              100
# 1                10002  ...                              100
# 2                10003  ...                              100
# 3                10004  ...                                0
# 4                10005  ...                              100
# 5                10006  ...                              100
# 6                10007  ...                              100
# 7                10009  ...                              100
# 8                10010  ...                                0
# 9                10011  ...                              100
# 10               10012  ...                                0
# 11               10013  ...                              100
# 12               10014  ...                                0
# 13               10016  ...                              100
# 14               10017  ...                                0
# 15               10018  ...                              100
# 16               10019  ...                                0
# 17               10020  ...                                0
# 18               10021  ...                                0
# 19               10022  ...                              100
# 20               10023  ...                              100
# 21               10024  ...                              100
# 22               10025  ...                              100
# 23               10026  ...                                0
# 24               10027  ...                              100
# 25               10028  ...                                0
# 26               10029  ...                              100
# 27               10030  ...                                0
# 28               10031  ...                                0
# 29               10032  ...                              100
# ..                 ...  ...                              ...
# 206              11731  ...                                0
# 207              11798  ...                              100
# 208              11968  ...                                0
# 209              12423  ...                              100
# 210              12428  ...                              100
# 211              12435  ...                              100
# 212              12458  ...                                0
# 213              12466  ...                              100
# 214              12473  ...                                0
# 215              12528  ...                              100
# 216              12701  ...                              100
# 217              12733  ...                              100
# 218              12734  ...                              100
# 219              12737  ...                              100
# 220              12750  ...                              100
# 221              12751  ...                              100
# 222              12754  ...                              100
# 223              12758  ...                              100
# 224              12759  ...                              100
# 225              12763  ...                              100
# 226              12764  ...                              100
# 227              12768  ...                              100
# 228              12779  ...                              100
# 229              12783  ...                              100
# 230              12786  ...                              100
# 231              12788  ...                              100
# 232              12789  ...                              100
# 233              13731  ...                              100
# 234              16091  ...                                0
# 235              20459  ...                                0
#
# [236 rows x 46 columns]

# %%
#Run this cell to see if you passed the test.  
_ = ok.grade('q04')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# **Question 5.**
#
# ### Importing CSV into a Pandas Dataframe
# - Comma delimited files are a common way of transmitting data.
# - Data for different columns is separated by a comma.
# - It is possible to open a csv in different ways, but Pandas is the easiest.
# - Data structured like CSV's are extremely common and known as tabular data.
# - Pandas will give access to many useful methods for working with data.
# - `pandas` is often imported as the abbreviated `pd`.
#
# ### Download CSV from Web to Colab using `wget`
# Click this link [https://data.cityofnewyork.us/api/views/kku6-nxdu/rows.csv?accessType=DOWNLOAD](https://data.cityofnewyork.us/api/views/kku6-nxdu/rows.csv?accessType=DOWNLOAD)
# to download the file to your local computer.
#
# To get the file onto the colab computational environment, the easiest way is to use wget.  If you have something on google drive, saving
#
# `!wget -O <filename you want to save to> <link to file>`
#
# For example:
# `!wget -O foo.csv https://data.us/122/?accessType=DOWNLOAD`
#
# You can read more about wget [here](https://www.electrictoolbox.com/wget-save-different-filename/).
#
# **Note that this is not a strategy for data that needs to remain secured, as anyone with access to your notebook would also gain access to the file.**

# %%
#Insert your wget command here
# !wget -O Demographic_Statistics_By_Zip_Code.csv https://data.cityofnewyork.us/api/views/kku6-nxdu/rows.csv?accessType=DOWNLOAD
# Out:
# --2019-08-30 20:13:38--  https://data.cityofnewyork.us/api/views/kku6-nxdu/rows.csv?accessType=DOWNLOAD
# Resolving data.cityofnewyork.us (data.cityofnewyork.us)... 52.206.68.26, 52.206.140.199, 52.206.140.205
# Connecting to data.cityofnewyork.us (data.cityofnewyork.us)|52.206.68.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘Demographic_Statistics_By_Zip_Code.csv’
#
# Demographic_Statist     [ <=>                ]  26.71K  --.-KB/s    in 0s
#
# 2019-08-30 20:13:38 (265 MB/s) - ‘Demographic_Statistics_By_Zip_Code.csv’ saved [27350]

# %%
# This will load the local name.csv file into a Pandas dataframe.  We will work with these a lot in the future.
import pandas as pd # This line imports the pandas package. 
dfcsv = pd.read_csv('Demographic_Statistics_By_Zip_Code.csv') 
dfcsv
# Out:
#      JURISDICTION NAME  ...  PERCENT PUBLIC ASSISTANCE TOTAL
# 0                10001  ...                              100
# 1                10002  ...                              100
# 2                10003  ...                              100
# 3                10004  ...                                0
# 4                10005  ...                              100
# 5                10006  ...                              100
# 6                10007  ...                              100
# 7                10009  ...                              100
# 8                10010  ...                                0
# 9                10011  ...                              100
# 10               10012  ...                                0
# 11               10013  ...                              100
# 12               10014  ...                                0
# 13               10016  ...                              100
# 14               10017  ...                                0
# 15               10018  ...                              100
# 16               10019  ...                                0
# 17               10020  ...                                0
# 18               10021  ...                                0
# 19               10022  ...                              100
# 20               10023  ...                              100
# 21               10024  ...                              100
# 22               10025  ...                              100
# 23               10026  ...                                0
# 24               10027  ...                              100
# 25               10028  ...                                0
# 26               10029  ...                              100
# 27               10030  ...                                0
# 28               10031  ...                                0
# 29               10032  ...                              100
# ..                 ...  ...                              ...
# 206              11731  ...                                0
# 207              11798  ...                              100
# 208              11968  ...                                0
# 209              12423  ...                              100
# 210              12428  ...                              100
# 211              12435  ...                              100
# 212              12458  ...                                0
# 213              12466  ...                              100
# 214              12473  ...                                0
# 215              12528  ...                              100
# 216              12701  ...                              100
# 217              12733  ...                              100
# 218              12734  ...                              100
# 219              12737  ...                              100
# 220              12750  ...                              100
# 221              12751  ...                              100
# 222              12754  ...                              100
# 223              12758  ...                              100
# 224              12759  ...                              100
# 225              12763  ...                              100
# 226              12764  ...                              100
# 227              12768  ...                              100
# 228              12779  ...                              100
# 229              12783  ...                              100
# 230              12786  ...                              100
# 231              12788  ...                              100
# 232              12789  ...                              100
# 233              13731  ...                              100
# 234              16091  ...                                0
# 235              20459  ...                                0
#
# [236 rows x 46 columns]

# %%
#Run this cell to see if you passed the test.  
_ = ok.grade('q05')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# ### Git and Github
# Do some investigation on your own and summarize 3 reasons why Git and Github are important tools for data scientists.

# %%
#Answer here
man1= """

#Answer here
As you have mentioned in class that the world is built on git. I have heard a rumor that Linux which is cool OS was build on git. People from all over the world can make contribution to it.  
As for data scientists, we can create repository for free and cooperation with others. Meanwhile, the histroy version of code minimize the consequences caused by accidents.  
There are lots of open sources information, instructions available on Github which makes the website a good learning tool.  
Github uses green rectangle box to record users' contribution on Github.In other word, Github can be a resume for coders.    
Recently, Github has made some updates that in the main page, people can see more repositories recommended by Github algorithm. Also, users can set status on our own.  
So, in my opinion, Github is not only a code tool to cooperate with other people showing the truth meaning of open source, but also a good resume.  

"""

# %% [markdown]
# ## Enter your information
# This is required to make sure that you get credit for the assignment.

# %%
course="mgmt6560"   #course number
section="Lally"          #section 
first_name="Yihui"   #For example, "jason"
last_name="Yang"    #For example, "kuruzovich"
student_id="661979332"       #for example "kuruzj"
student_email="yangy34@rpi.edu"    #for example "kuruzj@rpi.edu"
collaborators = "Guanting Gai"  #You can speak with others regarding the assignment, but all typed work must be your own.

# %%
#Run this cell to see if you passed the test.  
_ = ok.grade('qname')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# ## SUBMIT TO GITHUB
# Your final file must be submitted to GitHub.

# %%
#Please run this at end to show that all tests were passed. 
import os
_ = [ok.grade(q[:-3]) for q in os.listdir("tests") if q.startswith('q')]

# %% [markdown]
# ## Homework Rubric
# The following Rubric will be used to grade homwork.
# 4 pts. x 6 questions.
# 6 points for commit to github and 0 errors.
# 30 points total.
#
# ### MAKE SURE YOU CHECK THE ONLINE REPOSITORY THAT YOUR WORK IS SUCCESSFULLY SAVED TO YOUR PRIVATE RESPOSITORY ON  [GITHUB](https://github.com).
#
# ```
# The repository will be in the format:
# https://github.com/rpi-intro-ml-app-<semester>-<year>/assignment-1-<your github id>
# ```
#
#
# ### MAKE SURE THAT THIS ENTIRE NOTEBOOK RUNS WITHOUT ERRORS. TO TEST THIS DO RUNTIME --> RESTART AND RUN ALL
#
# It should complete till the end.

# %% [markdown]
# This work is licensed under the [Creative Commons Attribution 4.0 International](https://creativecommons.org/licenses/by/4.0/) license agreement.
